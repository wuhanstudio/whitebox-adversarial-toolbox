# %% [markdown]
# # Load image

# %%
import cv2
import matplotlib.pyplot as plt

# %%
dog = cv2.imread('dog.jpg')
dog = cv2.cvtColor(dog, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(dog)

# %% [markdown]
# # MobileNetV1 SSD Inference

# %%
import torch
from what.models.detection.ssd.mobilenet_v1_ssd import MobileNetV1SSD

# %%
# Initialize the model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = MobileNetV1SSD(pretrained=True, is_test=True, device=device)

# %%
# Run inference
_, boxes, labels, probs = model.predict(dog, 10, 0.4)
# Out:
# FPS:  152

# %% [markdown]
# # Display output

# %%
from what.models.detection.utils.box_utils import draw_bounding_boxes

# %%
output = draw_bounding_boxes(dog, boxes, labels, model.class_names, probs)

# %%
plt.imshow(output)
